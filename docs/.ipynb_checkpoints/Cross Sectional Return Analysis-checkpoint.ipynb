# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import returnbyfactors
import alphalens

# %%
data = pd.read_csv(r'/home/ibrahim/Desktop/internship_project/data/Price.csv',index_col='Unnamed: 0')

# %%
pivotdata = data.pivot_table(values='adjusted_close',index='date',columns='symbol')
pivotdata.index = pd.to_datetime(pivotdata.index)
#pivotdata = pivotdata.dropna(thresh=15,axis=0)

# %%
pivotdata
# Out:
# symbol      ABANA  ACIBD  ACSEL  ADANA  ADBGR   ADEL  ADESE  ADNAC  AEFES  \
# date
# 1990-01-02    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-03    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-05    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-08    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-09    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-10    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-11    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-12    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-16    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990-01-17    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
pivotdata = pivotdata['2000-01-01':]

# %%
returns = pivotdata.pct_change()

# %%
scores = returns.rolling(window=250,min_periods=220).std().dropna(how='all',axis=0)
scores_alphalens= scores.copy()

# %%
factor_scores = returnbyfactors.analyze_by_score(pivotdata,scores,nofgroups=9,return_range=[20,40,60])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-d93a56aab017> in <module>
# ----> 1 factor_scores = returnbyfactors.analyze_by_score(pivotdata,scores,nofgroups=9,return_range=[20,40,60])
#
# ~/anaconda3/lib/python3.7/site-packages/returnbyfactors/returnbyfactors.py in analyze_by_score(pivotdata, factor_score, nofgroups, return_range, filter_by_zscore)
#      33     count=0
#      34     for i in grouplabeled.values:
# ---> 35         k = pd.qcut(i,nofgroups,labels=list(range(1,nofgroups+1)),duplicates='drop')
#      36         grouplabeled.values[count] = k
#      37         count=count+1
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     304     fac, bins = _bins_to_cuts(x, bins, labels=labels,
#     305                               precision=precision, include_lowest=True,
# ...

# %%
factor_scores
# Out:
#         20dayreturn  40dayreturn  60dayreturn
# index
# Group1    -0.007385    -0.015304    -0.022478
# Group2    -0.000657    -0.001687    -0.002662
# Group3     0.001959     0.003908     0.006298
# Group4     0.003056     0.006255     0.009329
# Group5     0.003814     0.007464     0.010709
# Group6     0.002309     0.005402     0.008296
# Group7     0.002156     0.006428     0.010311
# Group8    -0.000522    -0.001149    -0.001638
# Group9    -0.004731    -0.011316    -0.018165

# %%
factor_scores.plot(kind='bar')

# %%
scores_alphalens = scores_alphalens.unstack()
scores_alphalens = scores_alphalens.reset_index(level=[0,1])
scores_alphalens.columns = ['symbol', 'date', 'factor']
scores_alphalens = scores_alphalens.set_index(['date','symbol'])

# %%
scores_alphalens
# Out:
#                      factor
# date       symbol
# 2000-11-17 ABANA   0.042841
# 2000-11-20 ABANA   0.042814
# 2000-11-21 ABANA   0.042717
# 2000-11-22 ABANA   0.042696
# 2000-11-23 ABANA   0.042794
# 2000-11-24 ABANA   0.042698
# 2000-11-27 ABANA   0.042765
# 2000-11-28 ABANA   0.042862
# 2000-11-29 ABANA   0.042773
# 2000-11-30 ABANA   0.042893
# 2000-12-01 ABANA   0.043295
# 2000-12-04 ABANA   0.043584
# 2000-12-05 ABANA   0.043766
# 2000-12-06 ABANA   0.043992
# 2000-12-07 ABANA   0.044423
# 2000-12-08 ABANA   0.044329
# 2000-12-11 ABANA   0.044546
# 2000-12-12 ABANA   0.045247
# 2000-12-13 ABANA   0.045735
# 2000-12-14 ABANA   0.045751
# 2000-12-15 ABANA   0.046079
# 2000-12-18 ABANA   0.046086
# 2000-12-19 ABANA   0.046065
# 2000-12-20 ABANA   0.045969
# 2000-12-21 ABANA   0.046136
# 2000-12-22 ABANA   0.046068
# 2001-01-02 ABANA   0.046122
# 2001-01-03 ABANA   0.046047
# 2001-01-04 ABANA   0.045960
# 2001-01-05 ABANA   0.045916
# ...                     ...
# ...

# %%
factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor=scores_alphalens,prices=pivotdata,quantiles=9 ,periods=(20, 40, 60))
# Out:
# Dropped 28.7% entries from factor data: 28.7% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!

# %%
alphalens.tears.create_full_tear_sheet(factor_data)

# %%
factor_scores.plot(kind='bar')
